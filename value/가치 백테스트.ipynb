# %%
import pandas as pd
import numpy as np

# %%
baseinfo = pd.read_pickle('baseinfo.pkl')
per_hist = pd.read_pickle('per_hist.pkl')
pbr_hist = pd.read_pickle('pbr_hist.pkl')

# %%
pbr_hist
# Out:
#             A005930   A373220  A000660   A207940  A051910  A035420  A006400  \
# code
# 2023-03-02  1.19644  13.43189  0.99500  10.40599  2.44451  1.37364  2.96904
# 2023-03-01  1.19250  13.13061  1.00968  10.41947  2.45172  1.39031  2.91050
# 2023-02-28  1.19250  13.13061  1.00968  10.41947  2.45172  1.39031  2.91050
# 2023-02-27  1.19054  12.75402  1.01646  10.37903  2.36879  1.38697  2.83523
# 2023-02-26  1.20628  12.82934  1.02775  10.55426  2.41206  1.38697  2.84359
# ...             ...       ...      ...       ...      ...      ...      ...
# 2020-11-01  1.43634       NaN  1.06931   9.86032  2.64621  5.55075  2.33503
# 2020-10-31  1.43634       NaN  1.06931   9.86032  2.64621  5.55075  2.33503
# 2020-10-30  1.43634       NaN  1.06931   9.86032  2.64621  5.55075  2.33503
# 2020-10-29  1.47440       NaN  1.09340  10.07720  2.81945  5.71344  2.27956
# 2020-10-28  1.49724       NaN  1.10946   9.20972  2.78047  5.71344  2.27164
#
# ...

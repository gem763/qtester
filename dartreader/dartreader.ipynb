# %%
import OpenDartReader
api_key = 'ea63013597cabbdab6bad54c2c0371d4bcd72113'
dart = OpenDartReader(api_key)

# %%
dart.list('삼성전자')
# Out:
#      corp_code corp_name stock_code corp_cls              report_nm  \
# 0     00126380      삼성전자     005930        Y    임원ㆍ주요주주특정증권등소유상황보고서
# 1     00126380      삼성전자     005930        Y               정기주주총회결과
# 2     00126380      삼성전자     005930        Y        사업보고서 (2022.12)
# 3     00126380      삼성전자     005930        Y         최대주주등소유주식변동신고서
# 4     00126380      삼성전자     005930        Y    임원ㆍ주요주주특정증권등소유상황보고서
# ...        ...       ...        ...      ...                    ...
# 5719  00126380      삼성전자     005930        Y           채무보증(담보제공포함)
# 5720  00126380      삼성전자     005930        Y          최대주주등을위한금전의대여
# 5721  00126380      삼성전자     005930        Y        감사보고서 (1999.12)
# 5722  00126380      삼성전자     005930        Y  [기재정정]반기보고서 (1999.06)
# 5723  00126380      삼성전자     005930        Y  [기재정정]사업보고서 (1998.12)
#
#             rcept_no  flr_nm  rcept_dt rm
# 0     20230316000646     안재용  20230316
# 1     20230315802179    삼성전자  20230315  유
# ...

# %%
dart.company_by_name('삼성전자')
# Out:
# [{'status': '000',
#   'message': '정상',
#   'corp_code': '00258999',
#   'corp_name': '삼성전자 서비스주식회사',
#   'corp_name_eng': 'SAMSUNNG ELECTRONICS SERVICE CO., LTD',
#   'stock_name': '삼성전자서비스',
#   'stock_code': '',
#   'ceo_nm': '송봉섭',
#   'corp_cls': 'E',
#   'jurir_no': '1301110049139',
#   'bizr_no': '1248158485',
#   'adres': '경기도 수원시 영통구 삼성로 290 (원천동)',
#   'hm_url': 'www.samsungsvc.co.kr',
#   'ir_url': '',
#   'phn_no': '031-270-2177',
#   'fax_no': '031-270-2106',
#   'induty_code': '95',
#   'est_dt': '19981027',
#   'acc_mt': '12'},
#  {'status': '000',
#   'message': '정상',
#   'corp_code': '01345812',
#   'corp_name': '삼성전자서비스씨에스 주식회사',
#   'corp_name_eng': 'SAMSUNG ELECTRONICS SERVICE CUSTOMER SATISFACTION., LTD.',
#   'stock_name': '삼성전자서비스씨에스',
#   'stock_code': '',
#   'ceo_nm': '이명옥',
#   'corp_cls': 'E',
#   'jurir_no': '1358110352541',
#   'bizr_no': '7898701103',
#   'adres': '경기도 수원시 영통구 중부대로 324 (매탄동, KT동수원지사)',
#   'hm_url': '',
#   'ir_url': '',
# ...

# %%
fstate = dart.finstate('삼성전자', 2022); fstate
# Out:
#           rcept_no reprt_code bsns_year corp_code stock_code fs_div   fs_nm  \
# 0   20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 1   20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 2   20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 3   20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 4   20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 5   20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 6   20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 7   20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 8   20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 9   20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# 10  20230307000542      11011      2022  00126380     005930    CFS  연결재무제표
# ...

# %%
dart.find_corp_code('005930')
# Out:
# '00126380'

# %%
dart.find_corp_code('삼성전자')
# Out:
# '00126380'

# %%
fstate.columns
# Out:
# Index(['rcept_no', 'reprt_code', 'bsns_year', 'corp_code', 'stock_code',
#        'fs_div', 'fs_nm', 'sj_div', 'sj_nm', 'account_nm', 'thstrm_nm',
#        'thstrm_dt', 'thstrm_amount', 'frmtrm_nm', 'frmtrm_dt', 'frmtrm_amount',
#        'bfefrmtrm_nm', 'bfefrmtrm_dt', 'bfefrmtrm_amount', 'ord', 'currency'],
#       dtype='object')

# %%
fstate[['fs_nm', 'sj_nm', 'account_nm', 'thstrm_dt', 'thstrm_amount']]
# Out:
#      fs_nm  sj_nm  account_nm                thstrm_dt        thstrm_amount
# 0   연결재무제표  재무상태표        유동자산            2022.12.31 현재  218,470,581,000,000
# 1   연결재무제표  재무상태표       비유동자산            2022.12.31 현재  229,953,926,000,000
# 2   연결재무제표  재무상태표        자산총계            2022.12.31 현재  448,424,507,000,000
# 3   연결재무제표  재무상태표        유동부채            2022.12.31 현재   78,344,852,000,000
# 4   연결재무제표  재무상태표       비유동부채            2022.12.31 현재   15,330,051,000,000
# 5   연결재무제표  재무상태표        부채총계            2022.12.31 현재   93,674,903,000,000
# 6   연결재무제표  재무상태표         자본금            2022.12.31 현재      897,514,000,000
# 7   연결재무제표  재무상태표       이익잉여금            2022.12.31 현재  337,946,407,000,000
# 8   연결재무제표  재무상태표        자본총계            2022.12.31 현재  354,749,604,000,000
# 9   연결재무제표  손익계산서         매출액  2022.01.01 ~ 2022.12.31  302,231,360,000,000
# 10  연결재무제표  손익계산서        영업이익  2022.01.01 ~ 2022.12.31   43,376,630,000,000
# ...

# %%
dart.finstate_all('005930', 2022)
# Out:
# reprt_code='11011', fs_div='CFS' (사업보고서, 연결제무제표)'
#            rcept_no reprt_code bsns_year corp_code sj_div  sj_nm  \
# 0    20230307000542      11011      2022  00126380     BS  재무상태표
# 1    20230307000542      11011      2022  00126380     BS  재무상태표
# 2    20230307000542      11011      2022  00126380     BS  재무상태표
# 3    20230307000542      11011      2022  00126380     BS  재무상태표
# 4    20230307000542      11011      2022  00126380     BS  재무상태표
# ..              ...        ...       ...       ...    ...    ...
# 180  20230307000542      11011      2022  00126380    SCE  자본변동표
# 181  20230307000542      11011      2022  00126380    SCE  자본변동표
# 182  20230307000542      11011      2022  00126380    SCE  자본변동표
# 183  20230307000542      11011      2022  00126380    SCE  자본변동표
# 184  20230307000542      11011      2022  00126380    SCE  자본변동표
#
#                                             account_id       account_nm  \
# ...
